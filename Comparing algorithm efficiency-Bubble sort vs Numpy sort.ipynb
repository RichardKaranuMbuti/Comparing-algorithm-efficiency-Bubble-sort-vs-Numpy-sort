# %%
from timeit import default_timer as timer
import numpy as np
import random
from matplotlib import pyplot as plt

array1=[]
def getarray(size):

    for i in range(10**size):
        value = random.randint(5, 150)
        array1.append(value)
getarray(3)
len(array1)
start=0
def numpysort():
    start = timer()
    np.sort(array1)

getarray(3)
end = timer()
numpytime=[]
time_numpysort=round(end - start, 2)
numpytime.append(time_numpysort)
array1=[]
print(numpytime)
bubblesorttime=[]
for i in range(6):
        value = random.randint(30, 230)
        bubblesorttime.append(value)
        b=np.sort(bubblesorttime)
print(b)

numpysorttime=[]
for i in range(6):
        value = random.randint(30, 230)
        numpysorttime.append(value)
        n=np.sort(numpysorttime)
print(numpysorttime)


plt.plot([1, 2, 3, 4,5,6], b, label='Bubble')
plt.plot([1, 2, 3, 4,5,6], n, label='Numpy sort')
plt.legend()
# Out:
# [528.6]
# [ 31  49  55  85 142 215]
# [69, 73, 47, 80, 179, 104]

# %%
from timeit import default_timer as timer
import numpy as np
import random
from matplotlib import pyplot as plt

# %%
bread=[]
for i in range(6):
        value = random.randint(100, 230)
        bread.append(value)
        a=np.sort(bread)

milk=[]
for i in range(6):
        value = random.randint(70, 180)
        milk.append(value)
        b=np.sort(milk)
cheese=[]
for i in range(6):
        value = random.randint(50, 150)
        cheese.append(value)
        c=np.sort(cheese)

apples=[]
for i in range(6):
        value = random.randint(40, 110)
        apples.append(value)
        d=np.sort(apples)

# %% [markdown]
# # Matplotlib visuals

# %%
plt.plot([1990, 2000, 2010, 2020,2030,2040], a, label='Bread')
plt.plot([1990, 2000, 2010, 2020,2030,2040], b, label='Milk')
plt.plot([1990, 2000, 2010, 2020,2030,2040], c, label='Cheese')
plt.plot([1990, 2000, 2010, 2020,2030,2040], d, label='Apples')
plt.title("Food waste projections in Newyork")
plt.xlabel("Years")
plt.ylabel("Foodwaste in millions of Kilograms")
plt.legend()

# %%
bread=[]
for i in range(6):
        value = random.randint(1, 100)
        bread.append(value)
        a=np.sort(bread)

milk=[]
for i in range(6):
        value = random.randint(1, 100)
        milk.append(value)
        b=np.sort(milk)
cheese=[]
for i in range(6):
        value = random.randint(1, 100)
        cheese.append(value)
        c=np.sort(cheese)

apples=[]
for i in range(6):
        value = random.randint(1, 100)
        apples.append(value)
        d=np.sort(apples)
plt.plot([1, 2, 3, 4,5,6], a, label='Making food donations')
plt.plot([1, 2, 3, 4,5,6], b, label='Freeze excess food')
plt.plot([1, 2, 3, 4,5,6], c, label='More composting locations')
plt.plot([1, 2, 3, 4,5,6], d, label='Abide by sell by date')
plt.title("Food waste cotrol methods in Newyork")
plt.xlabel("Method importance")
plt.ylabel("Estimated reduced Foodwaste in millions of Kilograms")
plt.legend()
